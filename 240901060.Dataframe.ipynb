# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randn(4,3),index=['a','c','d','f'],columns=['one','two','three'])
df=df.reindex(['a','b','c','d','e','f'])
print("Original DataFrame with NaN\n",df)
print("\n")
print("Dropped DataFrame\n",df.dropna())
print("\n")
df=pd.DataFrame(np.random.randn(4,3),index=['a','c','d','f'],columns=['one','two','three'])
df=df.reindex(['a','b','c','d','e','f'])
print("Original DataFrame:\n",df)
print("\n")
print("NaN replaced with '0'\n")
print(df.fillna(0))
df=pd.DataFrame(np.random.randn(4,3),index=['a','c','d','f'],columns=['one','two','three'])
df=df.reindex(['a','b','c','d','e','f'])
print("Original DataFrame:\n",df)
print("\nNan-with True fill:\n")
print(df['one'].isnull())
# Out:
# Original DataFrame with NaN
#          one       two     three
# a -0.988276  0.241061 -0.964974
# b       NaN       NaN       NaN
# c -1.062538 -0.485417  0.073453
# d -0.761882 -0.560778 -0.598585
# e       NaN       NaN       NaN
# f -1.954253 -0.726227 -1.194697
#
#
# Dropped DataFrame
#          one       two     three
# a -0.988276  0.241061 -0.964974
# c -1.062538 -0.485417  0.073453
# d -0.761882 -0.560778 -0.598585
# f -1.954253 -0.726227 -1.194697
#
#
# Original DataFrame:
#          one       two     three
# a  0.539584 -0.559866 -1.304941
# b       NaN       NaN       NaN
# c -0.189621 -0.855037 -0.291910
# d  0.452895 -0.961442 -0.117835
# e       NaN       NaN       NaN
# f  0.013929 -0.920644 -0.481789
#
#
# NaN replaced with '0'
#
#         one       two     three
# a  0.539584 -0.559866 -1.304941
# b  0.000000  0.000000  0.000000
# c -0.189621 -0.855037 -0.291910
# d  0.452895 -0.961442 -0.117835
# e  0.000000  0.000000  0.000000
# f  0.013929 -0.920644 -0.481789
# Original DataFrame:
#          one       two     three
# a  0.703075  0.101225 -1.240653
# b       NaN       NaN       NaN
# c  0.556586  0.950108 -2.118838
# d  0.726626 -1.141752  2.130819
# e       NaN       NaN       NaN
# f  0.094542 -0.367491  1.115739
#
# Nan-with True fill:
#
# a    False
# b     True
# c    False
# d    False
# e     True
# f    False
# Name: one, dtype: bool
